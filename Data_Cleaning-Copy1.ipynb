# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Read in our csv data (>100Mb so takes a while)

df_actors=pd.read_csv("../name.basics.tsv.gz",sep="\t")
df_main=pd.read_csv("../title.basics.tsv.gz",sep="\t")
df_ratings=pd.read_csv("../title.ratings.tsv.gz",sep="\t")

# %%
# How many different genres are there? We have one for each unique combination -> E.g. (Action, Comedy, Romance)
len(df_main.genres.unique())
# Out:
# 2236

# %%
# What types of data is in our dataset? 
(df_main.titleType.unique())
# Out:
# array(['short', 'movie', 'tvMovie', 'tvSeries', 'tvEpisode', 'tvShort',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %%
# We are just looking at film so create new dataset and save as csv (to upload)
df_movies=df_main.loc[df_main["titleType"]=="movie",:]

df_movies.to_csv(r'data/df_movies_dirty.csv')

# %%
#Remove nulls from genres
df_movies=df_movies.loc[df_movies["genres"]!="\\N",:]
# Out:
# \N      2417
# 1921    1247
# 1920    1108
# 1979     996
# 1990     988
# 1984     966
# 1922     961
# 2016     947
# 1985     936
# 1992     930
# 1980     926
# 1993     919
# 1999     915
# 1978     904
# 1996     894
# 1983     894
# 2017     893
# 1995     886
# 1971     885
# 1998     880
# 1982     871
# 1991     869
# 1981     866
# 1977     862
# 1997     856
# 1987     828
# 1986     828
# 1975     817
# 1994     816
# 1919     806
#         ...
# 1909      37
# 1958      37
# 1966      36
# 1962      36
# 1959      36
# 1910      32
# 2022      30
# 1951      28
# 1909      26
# 1911      26
# 1910      22
# 2021      20
# 1898      17
# 1908      14
# 1971      14
# 1906      11
# 1903       8
# 1907       8
# 1905       6
# 2023       5
# 1900       5
# 1904       5
# 1899       3
# 1973       3
# 1972       2
# 2024       2
# 1902       2
# 1905       1
# 1983       1
# 1901       1
# Name: startYear, Length: 195, dtype: int64

# %%
df_movies.startYear.astype("int64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5edc661a555c> in <module>()
# ----> 1 df_movies.startYear.astype("int64")
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
# ...

# %%
df_movies.loc[df_movies["startYear"]  "2019"]
# Out:
#   File "<ipython-input-25-abd6fcb93eea>", line 1
#     df_movies.loc[df_movies["genres"]  "2019"]
#                                             ^
# SyntaxError: invalid syntax

# %%
(df_movies.loc[df_movies["genres"]!=r"\N",:])
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 145      tt0000147     movie
# 332      tt0000335     movie
# 571      tt0000574     movie
# 611      tt0000615     movie
# 626      tt0000630     movie
# 669      tt0000675     movie
# 670      tt0000676     movie
# 673      tt0000679     movie
# 730      tt0000739     movie
# 784      tt0000793     movie
# 877      tt0000886     movie
# 931      tt0000941     movie
# 1017     tt0001028     movie
# 1038     tt0001049     movie
# 1048     tt0001059     movie
# 1101     tt0001112     movie
# 1104     tt0001115     movie
# 1136     tt0001147     movie
# 1152     tt0001163     movie
# 1164     tt0001175     movie
# 1173     tt0001184     movie
# 1229     tt0001240     movie
# 1247     tt0001258     movie
# 1266     tt0001277     movie
# 1274     tt0001285     movie
# 1327     tt0001338     movie
# 1330     tt0001341     movie
# 1348     tt0001359     movie
# 1359     tt0001370     movie
# ...            ...       ...
# ...
